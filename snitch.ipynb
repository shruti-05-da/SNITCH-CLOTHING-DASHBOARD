# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### load datset

# %%
snitch=pd.read_csv(r"C:\ev project\Snitch_Fashion_Sales_Uncleaned.csv")

# %% [markdown]
# ### clean dataset

# %%
snitch
# Out:
#       Order_ID      Customer_Name Product_Category       Product_Name  \
# 0         1000     Brian Thompson            Jeans     Slim Fit Jeans
# 1         1001         Shaun Ross            Jeans     Slim Fit Jeans
# 2         1002       Sarah Snyder          Jackets        Puffer Coat
# 3         1003         Jay Briggs            Shoes            Loafers
# 4         1004        Maria Blake      Accessories              Belts
# ...        ...                ...              ...                ...
# 2495      3495     Allen Williams         T-Shirts  Oversized T-shirt
# 2496      3496      Jonathan Hill            Shoes            Loafers
# 2497      3497  Alejandro Cochran          Jackets      Bomber Jacket
# 2498      3498      Angela Adkins            Jeans       Straight Cut
# 2499      3499     Zachary Werner         T-Shirts        Graphic Tee
#
#       Units_Sold  Unit_Price  Discount_%  Sales_Amount  Order_Date       City  \
# ...

# %%
snitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2500 non-null   int64
#  1   Customer_Name     2500 non-null   object
#  2   Product_Category  2500 non-null   object
#  3   Product_Name      2500 non-null   object
#  4   Units_Sold        1194 non-null   float64
#  5   Unit_Price        1290 non-null   float64
#  6   Discount_%        849 non-null    float64
#  7   Sales_Amount      2500 non-null   float64
#  8   Order_Date        1894 non-null   object
#  9   City              2500 non-null   object
#  10  Segment           1679 non-null   object
#  11  Profit            2500 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 234.5+ KB

# %%
snitch.columns=snitch.columns.str.lower()

# %%
snitch.head()
# Out:
#    order_id   customer_name product_category    product_name  units_sold  \
# 0      1000  Brian Thompson            Jeans  Slim Fit Jeans         NaN
# 1      1001      Shaun Ross            Jeans  Slim Fit Jeans         1.0
# 2      1002    Sarah Snyder          Jackets     Puffer Coat         1.0
# 3      1003      Jay Briggs            Shoes         Loafers         2.0
# 4      1004     Maria Blake      Accessories           Belts         1.0
#
#    unit_price  discount_%  sales_amount  order_date       city segment  \
# 0      842.00        0.60          0.00  2025-02-27      Delhi     B2C
# 1         NaN         NaN          0.00  2025-07-15  Ahmedabad     NaN
# 2      637.82         NaN          0.00  02-01-2025     Mumbai     B2B
# 3     2962.27         NaN          0.00  18-06-2025  bengaluru     B2B
# 4     2881.07        0.27       2103.18         NaN   hyderbad     NaN
#
#     profit
# 0  2137.45
# 1  1588.15
# 2  -158.03
# 3  2296.50
# 4    63.66

# %%
snitch["units_sold"].fillna(round(snitch["profit"]/snitch["unit_price"]),inplace=True)
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_7316\3722638309.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   snitch["units_sold"].fillna(round(snitch["profit"]/snitch["unit_price"]),inplace=True)

# %%
snitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          2500 non-null   int64
#  1   customer_name     2500 non-null   object
#  2   product_category  2500 non-null   object
#  3   product_name      2500 non-null   object
#  4   units_sold        1875 non-null   float64
#  5   unit_price        1290 non-null   float64
#  6   discount_%        849 non-null    float64
#  7   sales_amount      2500 non-null   float64
#  8   order_date        1894 non-null   object
#  9   city              2500 non-null   object
#  10  segment           1679 non-null   object
#  11  profit            2500 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 234.5+ KB

# %%
snitch
# Out:
#       order_id      customer_name product_category       product_name  \
# 0         1000     Brian Thompson            Jeans     Slim Fit Jeans
# 1         1001         Shaun Ross            Jeans     Slim Fit Jeans
# 2         1002       Sarah Snyder          Jackets        Puffer Coat
# 3         1003         Jay Briggs            Shoes            Loafers
# 4         1004        Maria Blake      Accessories              Belts
# ...        ...                ...              ...                ...
# 2495      3495     Allen Williams         T-Shirts  Oversized T-shirt
# 2496      3496      Jonathan Hill            Shoes            Loafers
# 2497      3497  Alejandro Cochran          Jackets      Bomber Jacket
# 2498      3498      Angela Adkins            Jeans       Straight Cut
# 2499      3499     Zachary Werner         T-Shirts        Graphic Tee
#
#       units_sold  unit_price  discount_%  sales_amount  order_date       city  \
# ...

# %%
snitch.dropna(subset=["order_date"], inplace=True)

# %%
snitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1894 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1894 non-null   int64
#  1   customer_name     1894 non-null   object
#  2   product_category  1894 non-null   object
#  3   product_name      1894 non-null   object
#  4   units_sold        1425 non-null   float64
#  5   unit_price        991 non-null    float64
#  6   discount_%        633 non-null    float64
#  7   sales_amount      1894 non-null   float64
#  8   order_date        1894 non-null   object
#  9   city              1894 non-null   object
#  10  segment           1270 non-null   object
#  11  profit            1894 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 192.4+ KB

# %%
snitch["sales_amount"]=snitch["unit_price"]-(snitch["unit_price"]*snitch["discount_%"])

# %%
snitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1894 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1894 non-null   int64
#  1   customer_name     1894 non-null   object
#  2   product_category  1894 non-null   object
#  3   product_name      1894 non-null   object
#  4   units_sold        1425 non-null   float64
#  5   unit_price        991 non-null    float64
#  6   discount_%        633 non-null    float64
#  7   sales_amount      329 non-null    float64
#  8   order_date        1894 non-null   object
#  9   city              1894 non-null   object
#  10  segment           1270 non-null   object
#  11  profit            1894 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 192.4+ KB

# %%
snitch.dropna(subset=["unit_price", "discount_%", "segment"],how="all", inplace=True)

# %%
snitch
# Out:
#       order_id     customer_name product_category     product_name  \
# 0         1000    Brian Thompson            Jeans   Slim Fit Jeans
# 2         1002      Sarah Snyder          Jackets      Puffer Coat
# 3         1003        Jay Briggs            Shoes          Loafers
# 5         1005     Samuel Miller         T-Shirts         Crop Top
# 6         1006       John Mclean            Jeans  Boyfriend Jeans
# ...        ...               ...              ...              ...
# 2490      3490   Preston Carroll          Dresses          Bodycon
# 2491      3491  Timothy Hamilton            Jeans  Boyfriend Jeans
# 2493      3493     Keith Manning          Dresses      Casual Midi
# 2496      3496     Jonathan Hill            Shoes          Loafers
# 2498      3498     Angela Adkins            Jeans     Straight Cut
#
#       units_sold  unit_price  discount_%  sales_amount  order_date       city  \
# 0            3.0      842.00        0.60      336.8000  2025-02-27      Delhi
# ...

# %%
snitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1697 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1697 non-null   int64
#  1   customer_name     1697 non-null   object
#  2   product_category  1697 non-null   object
#  3   product_name      1697 non-null   object
#  4   units_sold        1330 non-null   float64
#  5   unit_price        991 non-null    float64
#  6   discount_%        633 non-null    float64
#  7   sales_amount      329 non-null    float64
#  8   order_date        1697 non-null   object
#  9   city              1697 non-null   object
#  10  segment           1270 non-null   object
#  11  profit            1697 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 172.4+ KB

# %%
snitch["discount_%"].fillna(0,inplace=True)

# %%
snitch["sales_amount"].fillna(snitch["unit_price"],inplace=True)
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_7316\772657952.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   snitch["sales_amount"].fillna(snitch["unit_price"],inplace=True)

# %%
snitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1697 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1697 non-null   int64
#  1   customer_name     1697 non-null   object
#  2   product_category  1697 non-null   object
#  3   product_name      1697 non-null   object
#  4   units_sold        1330 non-null   float64
#  5   unit_price        991 non-null    float64
#  6   discount_%        1697 non-null   float64
#  7   sales_amount      991 non-null    float64
#  8   order_date        1697 non-null   object
#  9   city              1697 non-null   object
#  10  segment           1270 non-null   object
#  11  profit            1697 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 172.4+ KB

# %%
snitch["segment"].fillna("none",inplace=True)
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_7316\2870060842.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   snitch["segment"].fillna("none",inplace=True)

# %%
snitch
# Out:
#       order_id     customer_name product_category     product_name  \
# 0         1000    Brian Thompson            Jeans   Slim Fit Jeans
# 2         1002      Sarah Snyder          Jackets      Puffer Coat
# 3         1003        Jay Briggs            Shoes          Loafers
# 5         1005     Samuel Miller         T-Shirts         Crop Top
# 6         1006       John Mclean            Jeans  Boyfriend Jeans
# ...        ...               ...              ...              ...
# 2490      3490   Preston Carroll          Dresses          Bodycon
# 2491      3491  Timothy Hamilton            Jeans  Boyfriend Jeans
# 2493      3493     Keith Manning          Dresses      Casual Midi
# 2496      3496     Jonathan Hill            Shoes          Loafers
# 2498      3498     Angela Adkins            Jeans     Straight Cut
#
#       units_sold  unit_price  discount_%  sales_amount  order_date       city  \
# 0            3.0      842.00        0.60      336.8000  2025-02-27      Delhi
# ...

# %%
snitch.dropna(subset="units_sold",inplace=True)

# %%
snitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1330 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1330 non-null   int64
#  1   customer_name     1330 non-null   object
#  2   product_category  1330 non-null   object
#  3   product_name      1330 non-null   object
#  4   units_sold        1330 non-null   float64
#  5   unit_price        991 non-null    float64
#  6   discount_%        1330 non-null   float64
#  7   sales_amount      991 non-null    float64
#  8   order_date        1330 non-null   object
#  9   city              1330 non-null   object
#  10  segment           1330 non-null   object
#  11  profit            1330 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 135.1+ KB

# %%
snitch["unit_price"].fillna(0,inplace=True)
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_7316\579868972.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   snitch["unit_price"].fillna(0,inplace=True)

# %%
snitch["sales_amount"].fillna(0,inplace=True)
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_7316\692096929.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   snitch["sales_amount"].fillna(0,inplace=True)

# %%
snitch
# Out:
#       order_id     customer_name product_category       product_name  \
# 0         1000    Brian Thompson            Jeans     Slim Fit Jeans
# 2         1002      Sarah Snyder          Jackets        Puffer Coat
# 3         1003        Jay Briggs            Shoes            Loafers
# 6         1006       John Mclean            Jeans    Boyfriend Jeans
# 9         1009        Dale Perry         T-Shirts  Oversized T-shirt
# ...        ...               ...              ...                ...
# 2490      3490   Preston Carroll          Dresses            Bodycon
# 2491      3491  Timothy Hamilton            Jeans    Boyfriend Jeans
# 2493      3493     Keith Manning          Dresses        Casual Midi
# 2496      3496     Jonathan Hill            Shoes            Loafers
# 2498      3498     Angela Adkins            Jeans       Straight Cut
#
#       units_sold  unit_price  discount_%  sales_amount  order_date       city  \
# ...

# %%
snitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1330 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1330 non-null   int64
#  1   customer_name     1330 non-null   object
#  2   product_category  1330 non-null   object
#  3   product_name      1330 non-null   object
#  4   units_sold        1330 non-null   float64
#  5   unit_price        1330 non-null   float64
#  6   discount_%        1330 non-null   float64
#  7   sales_amount      1330 non-null   float64
#  8   order_date        1330 non-null   object
#  9   city              1330 non-null   object
#  10  segment           1330 non-null   object
#  11  profit            1330 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 135.1+ KB

# %%
snitch.drop(columns="order_id",inplace=True)

# %%
snitch
# Out:
#          customer_name product_category       product_name  units_sold  \
# 0       Brian Thompson            Jeans     Slim Fit Jeans         3.0
# 2         Sarah Snyder          Jackets        Puffer Coat         1.0
# 3           Jay Briggs            Shoes            Loafers         2.0
# 6          John Mclean            Jeans    Boyfriend Jeans         1.0
# 9           Dale Perry         T-Shirts  Oversized T-shirt         5.0
# ...                ...              ...                ...         ...
# 2490   Preston Carroll          Dresses            Bodycon         0.0
# 2491  Timothy Hamilton            Jeans    Boyfriend Jeans         0.0
# 2493     Keith Manning          Dresses        Casual Midi         5.0
# 2496     Jonathan Hill            Shoes            Loafers         4.0
# 2498     Angela Adkins            Jeans       Straight Cut         5.0
#
#       unit_price  discount_%  sales_amount  order_date       city segment  \
# ...

# %%
snitch.reset_index(drop=True, inplace=True)

# %%
snitch
# Out:
#          customer_name product_category       product_name  units_sold  \
# 0       Brian Thompson            Jeans     Slim Fit Jeans         3.0
# 1         Sarah Snyder          Jackets        Puffer Coat         1.0
# 2           Jay Briggs            Shoes            Loafers         2.0
# 3          John Mclean            Jeans    Boyfriend Jeans         1.0
# 4           Dale Perry         T-Shirts  Oversized T-shirt         5.0
# ...                ...              ...                ...         ...
# 1325   Preston Carroll          Dresses            Bodycon         0.0
# 1326  Timothy Hamilton            Jeans    Boyfriend Jeans         0.0
# 1327     Keith Manning          Dresses        Casual Midi         5.0
# 1328     Jonathan Hill            Shoes            Loafers         4.0
# 1329     Angela Adkins            Jeans       Straight Cut         5.0
#
#       unit_price  discount_%  sales_amount  order_date       city segment  \
# ...

# %%
snitch["units_sold"]=snitch["units_sold"].astype(int)

# %%
snitch
# Out:
#          customer_name product_category       product_name  units_sold  \
# 0       Brian Thompson            Jeans     Slim Fit Jeans           3
# 1         Sarah Snyder          Jackets        Puffer Coat           1
# 2           Jay Briggs            Shoes            Loafers           2
# 3          John Mclean            Jeans    Boyfriend Jeans           1
# 4           Dale Perry         T-Shirts  Oversized T-shirt           5
# ...                ...              ...                ...         ...
# 1325   Preston Carroll          Dresses            Bodycon           0
# 1326  Timothy Hamilton            Jeans    Boyfriend Jeans           0
# 1327     Keith Manning          Dresses        Casual Midi           5
# 1328     Jonathan Hill            Shoes            Loafers           4
# 1329     Angela Adkins            Jeans       Straight Cut           5
#
#       unit_price  discount_%  sales_amount  order_date       city segment  \
# ...

# %%
snitch["loss"] = snitch["profit"].where(snitch["profit"] < 0, other=0)

# %%
snitch
# Out:
#          customer_name product_category       product_name  units_sold  \
# 0       Brian Thompson            Jeans     Slim Fit Jeans           3
# 1         Sarah Snyder          Jackets        Puffer Coat           1
# 2           Jay Briggs            Shoes            Loafers           2
# 3          John Mclean            Jeans    Boyfriend Jeans           1
# 4           Dale Perry         T-Shirts  Oversized T-shirt           5
# ...                ...              ...                ...         ...
# 1325   Preston Carroll          Dresses            Bodycon           0
# 1326  Timothy Hamilton            Jeans    Boyfriend Jeans           0
# 1327     Keith Manning          Dresses        Casual Midi           5
# 1328     Jonathan Hill            Shoes            Loafers           4
# 1329     Angela Adkins            Jeans       Straight Cut           5
#
#       unit_price  discount_%  sales_amount  order_date       city segment  \
# ...

# %%
snitch.loc[snitch["profit"] < 0, "profit"] = 0

# %%
snitch
# Out:
#          customer_name product_category       product_name  units_sold  \
# 0       Brian Thompson            Jeans     Slim Fit Jeans           3
# 1         Sarah Snyder          Jackets        Puffer Coat           1
# 2           Jay Briggs            Shoes            Loafers           2
# 3          John Mclean            Jeans    Boyfriend Jeans           1
# 4           Dale Perry         T-Shirts  Oversized T-shirt           5
# ...                ...              ...                ...         ...
# 1325   Preston Carroll          Dresses            Bodycon           0
# 1326  Timothy Hamilton            Jeans    Boyfriend Jeans           0
# 1327     Keith Manning          Dresses        Casual Midi           5
# 1328     Jonathan Hill            Shoes            Loafers           4
# 1329     Angela Adkins            Jeans       Straight Cut           5
#
#       unit_price  discount_%  sales_amount  order_date       city segment  \
# ...

# %%
snitch["loss"] = snitch["loss"].abs()

# %%
snitch
# Out:
#          customer_name product_category       product_name  units_sold  \
# 0       Brian Thompson            Jeans     Slim Fit Jeans           3
# 1         Sarah Snyder          Jackets        Puffer Coat           1
# 2           Jay Briggs            Shoes            Loafers           2
# 3          John Mclean            Jeans    Boyfriend Jeans           1
# 4           Dale Perry         T-Shirts  Oversized T-shirt           5
# ...                ...              ...                ...         ...
# 1325   Preston Carroll          Dresses            Bodycon           0
# 1326  Timothy Hamilton            Jeans    Boyfriend Jeans           0
# 1327     Keith Manning          Dresses        Casual Midi           5
# 1328     Jonathan Hill            Shoes            Loafers           4
# 1329     Angela Adkins            Jeans       Straight Cut           5
#
#       unit_price  discount_%  sales_amount  order_date       city segment  \
# ...

# %%
snitch.to_excel("C:\\ev project\\snitch_cleaned.xlsx", index=False)
